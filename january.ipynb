# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
from scipy.optimize import minimize
import pandas as pd
from scipy.stats import poisson, uniform, expon, pareto
from tqdm import tqdm
from mdptoolbox import mdp, util
import itertools
from scipy.sparse import csr_matrix, lil_matrix
from matplotlib.patches import Patch
import math
import random
import sympy as sp
import sympy.stats as sps
from sympy.printing.latex import print_latex

# %% [markdown]
# # Linear rewards theo + sims
#
# ```
# gamma = 0
# p     = [1/4, 1/2, 3/4]
# alpha = [0.2, 0.25, 0.3, 0.35, 0.4]
# beta  = np.arange(0.25, 4.1, 0.25) # sims
# beta  = np.arange(0.01, 4.1, 0.01) # theo
# E     = 1
# ```

# %%
p0, p0p, p1, p0pp = sp.symbols('p_0 p_{00} p_1 p_{000}')
a, b, x, g, p, E  = sp.symbols('alpha beta x gamma p E')

# %%
p0fail = (1-p)*p1*sp.exp(-x) / (a*p*(1-sp.Min(1,sp.exp(-b+E)))+a*(1-p)*(1-sp.exp(-b)))
p0fail
# Out:
# p_1*(1 - p)*exp(-x)/(alpha*p*(1 - Min(1, exp(E - beta))) + alpha*(1 - p)*(1 - exp(-beta)))

# %%
f0failHi = a
f0failLo = a*sp.exp(-b+x)+a**2*(1-sp.exp(-b+x)) + a*(1-a)*(1-sp.exp(-b+x))*(a+(1-a)*g)
f0failLo
# Out:
# alpha**2*(1 - exp(-beta + x)) + alpha*(1 - alpha)*(1 - exp(-beta + x))*(alpha + gamma*(1 - alpha)) + alpha*exp(-beta + x)

# %%
loIntegrandFail = sp.simplify(p0fail * f0failLo)
loIntegralFail  = sp.simplify(sp.integrate(loIntegrandFail, (x, 0, b)))

# %%
hiIntegrandFail = sp.simplify(p0fail * f0failHi)
hiIntegralFail  = sp.simplify(sp.integrate(hiIntegrandFail, (x, b, sp.oo)))

# %%
p0success = p*p1*sp.exp(-x) / (a*p*(1-sp.Min(1,sp.exp(-b+E)))+a*(1-p)*(1-sp.exp(-b)))
p0success
# Out:
# p*p_1*exp(-x)/(alpha*p*(1 - Min(1, exp(E - beta))) + alpha*(1 - p)*(1 - exp(-beta)))

# %%
f0successHi = a
f0successLo = a*sp.exp(-b+E+x)+a**2*(1-sp.exp(-b+E+x)) + a*(1-a)*(1-sp.exp(-b+E+x))*(a+(1-a)*g)
f0successLo
# Out:
# alpha**2*(1 - exp(E - beta + x)) + alpha*(1 - alpha)*(1 - exp(E - beta + x))*(alpha + gamma*(1 - alpha)) + alpha*exp(E - beta + x)

# %%
loIntegrandSuccess = sp.simplify(p0success * f0successLo)
loIntegralSuccess  = sp.simplify(sp.integrate(loIntegrandSuccess, (x, 0, sp.Max(0,b-E))))

# %%
hiIntegrandSuccess = sp.simplify(p0success * f0successHi)
hiIntegralSuccess  = sp.simplify(sp.integrate(hiIntegrandSuccess, (x, sp.Max(0,b-E), sp.oo)))

# %%
full = loIntegralFail + hiIntegralFail + loIntegralSuccess + hiIntegralSuccess + p1*(3*a - a**2 + 2*a**2/(1-2*a))
full
# Out:
# p_1*(-alpha**2 + 2*alpha**2/(1 - 2*alpha) + 3*alpha) + Piecewise((p*p_1*((-alpha**2*gamma + alpha**2 + 2*alpha*gamma - 2*alpha - gamma)*exp(beta) + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma)*exp(beta - Max(0, -E + beta)) + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma - 1)*exp(E)*Max(0, -E + beta))/(p*exp(beta) - p - exp(beta) + 1), (exp(E - beta) >= 1) & Ne(-p*exp(beta) + p + exp(beta), 1)), (p*p_1*(-alpha**2*gamma + alpha**2 + 2*alpha*gamma - 2*alpha - gamma + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma - 1)*exp(E))*Max(0, -E + beta)/(p*exp(beta) - p - exp(beta) + 1), (exp(E - beta) >= 1) | ((exp(E - beta) >= 1) & Ne(-p*exp(E) + p + exp(beta), 1))), (p*p_1*((-alpha**2*gamma + alpha**2 + 2*alpha*gamma - 2*alpha - gamma)*exp(beta) + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma)*exp(beta - Max(0, -E + beta)) + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma - 1)*exp(E)*Max(0, -E + beta))/(p*exp(E) - p - exp(beta) + 1), Ne(-p*exp(E) + p + exp(beta), 1)), (p*p_1*(-alpha**2*gamma + alpha**2 + 2*alpha*gamma - 2*alpha - gamma + (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma - 1)*exp(E))*Max(0, -E + beta)/(p*exp(E) - p - exp(beta) + 1), True)) + Piecewise((-p*p_1*exp(beta - Max(0, -E + beta))/(p*exp(beta) - p - exp(beta) + 1), (exp(E - beta) >= 1) & Ne(-p*exp(beta) + p + exp(beta), 1)), (Piecewise((nan, Eq(p*p_1/(p*exp(beta) - p - exp(beta) + 1), 0)), (p*p_1*((-E + beta + Abs(E - beta))*Abs(p*p_1/(p*exp(beta) - p - exp(beta) + 1)) - oo)/(2*(p*exp(beta) - p - exp(beta) + 1)*Abs(p*p_1/(p*exp(beta) - p - exp(beta) + 1))), True)), (exp(E - beta) >= 1) | ((exp(E - beta) >= 1) & Ne(-p*exp(E) + p + exp(beta), 1))), (-p*p_1*exp(beta - Max(0, -E + beta))/(p*exp(E) - p - exp(beta) + 1), Ne(-p*exp(E) + p + exp(beta), 1)), (Piecewise((nan, Eq(p*p_1/(p*exp(E) - p - exp(beta) + 1), 0)), (p*p_1*((-E + beta + Abs(E - beta))*Abs(p*p_1/(p*exp(E) - p - exp(beta) + 1)) - oo)/(2*(p*exp(E) - p - exp(beta) + 1)*Abs(p*p_1/(p*exp(E) - p - exp(beta) + 1))), True)), True)) + Piecewise((p_1/(exp(beta) - 1), Ne(exp(beta), 1) & (exp(E - beta) >= 1)), (p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1), Ne(-p*exp(E) + p + exp(beta), 1)), (Piecewise((nan, Eq(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1), 0)), (p_1*(p - 1)*(-beta*Abs(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1)) + oo)/((p*exp(E) - p - exp(beta) + 1)*Abs(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1))), True)), Ne(beta, 0)), (Piecewise((nan, Eq(p_1/(exp(beta) - 1), 0)), (-p_1*(beta*Abs(p_1/(exp(beta) - 1)) - oo)/((exp(beta) - 1)*Abs(p_1/(exp(beta) - 1))), True)), (exp(E - beta) >= 1) | ((exp(E - beta) >= 1) & Ne(-p*exp(E) + p + exp(beta), 1))), (Piecewise((nan, Eq(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1), 0)), (p_1*(p - 1)*(-beta*Abs(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1)) + oo)/((p*exp(E) - p - exp(beta) + 1)*Abs(p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1))), True)), True)) + Piecewise((-p_1*(alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + beta*(alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma - 1) + gamma - (alpha**2*gamma - alpha**2 - 2*alpha*gamma + 2*alpha + gamma)*exp(beta))/(exp(beta) - 1), Ne(exp(beta), 1) & (exp(E - beta) >= 1)), (p_1*(-alpha**2*gamma*p + alpha**2*gamma + alpha**2*p - alpha**2 + 2*alpha*gamma*p - 2*alpha*gamma - 2*alpha*p + 2*alpha - beta*(alpha**2*gamma*p - alpha**2*gamma - alpha**2*p + alpha**2 - 2*alpha*gamma*p + 2*alpha*gamma + 2*alpha*p - 2*alpha + gamma*p - gamma - p + 1) - gamma*p + gamma + (alpha**2*gamma*p - alpha**2*gamma - alpha**2*p + alpha**2 - 2*alpha*gamma*p + 2*alpha*gamma + 2*alpha*p - 2*alpha + gamma*p - gamma)*exp(beta))/(p*exp(E) - p - exp(beta) + 1), Ne(-p*exp(E) + p + exp(beta), 1)), (beta*p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1), Ne(beta, 0)), (beta*p_1/(exp(beta) - 1), (exp(E - beta) >= 1) | ((exp(E - beta) >= 1) & Ne(-p*exp(E) + p + exp(beta), 1))), (beta*p_1*(p - 1)/(p*exp(E) - p - exp(beta) + 1), True))

# %%
p1_solved = 1/(1/(a*p*(1-sp.Min(1,sp.exp(-b+E))) + a*(1-p)*(1-sp.exp(-b))) + 1 + (1-a)/(1-2*a))
p1_solved
# Out:
# 1/(1 + 1/(alpha*p*(1 - Min(1, exp(E - beta))) + alpha*(1 - p)*(1 - exp(-beta))) + (1 - alpha)/(1 - 2*alpha))

# %%
fullLambda = sp.lambdify((a, b, g, p, E), full.evalf(subs={p1:p1_solved}))
fullLambda
# Out:
# <function _lambdifygenerated(alpha, beta, gamma, p, E)>

# %%
alphas    = [0.2, 0.25, 0.3, 0.35, 0.4]
betas     = np.arange(0.01, 4, 0.01)
ps        = [0.25, 0.5, 0.75] # using E=1
simBetas  = np.arange(0., 4.01, 0.25)
simBetas
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  ])

# %%
theoRes = []
for a in alphas:
    temp1 = []
    for b in betas:
        temp2 = []
        for p in ps:
            temp2.append(fullLambda(alpha=a, beta=b, gamma=0.0, p=p, E=1.))
        temp1.append(temp2)
    theoRes.append(temp1)
theoRes = np.array(theoRes)
theoRes.shape
# Out:
# (5, 399, 3)

# %%
simsRes = []
for a in alphas:
    temp1 = []
    for b in tqdm(simBetas):
        temp2 = []
        for p in ps:
            _, _, _, _, honestLin, attackLin = simAllRews(a=a, b=b, p=p, E=1, n=int(2e4))
            temp2.append(attackLin/(attackLin+honestLin))
        temp1.append(temp2)
    simsRes.append(temp1)
simsRes = np.array(simsRes)
simsRes.shape
# Out:
# 100%|██████████| 17/17 [00:05<00:00,  3.14it/s]
# 100%|██████████| 17/17 [00:05<00:00,  3.11it/s]
# 100%|██████████| 17/17 [00:05<00:00,  3.04it/s]
# 100%|██████████| 17/17 [00:05<00:00,  2.94it/s]
# 100%|██████████| 17/17 [00:05<00:00,  3.00it/s]
# (5, 17, 3)

# %%
f, axarr = plt.subplots(ncols=3, figsize=(14,4))

colors = ['maroon', 'lightseagreen', 'darkmagenta', 'peru', 'dodgerblue'] 
handles, labels = [], []

for i in range(3):
    ax = axarr[i]
    for j, a in enumerate(alphas):
        line, = ax.plot(betas, theoRes[j,:,i], linewidth=0.8, color=colors[j], 
                        label=r'$\alpha$={:0.2f} theo'.format(a))
        if i == 0:
            handles.append(line)
            labels.append(r'$\alpha$={:0.2f} theo'.format(a))

for i in range(3):
    ax = axarr[i]
    for j, a in enumerate(alphas):
        marker, = ax.plot(simBetas, simsRes[j,:,i], marker='o', color=colors[j], linestyle='none', 
                          fillstyle='none', label=r'$\alpha$={:0.2f} sim'.format(a))
        if i == 0:
            handles.append(marker)
            labels.append(r'$\alpha$={:0.2f} sim'.format(a))


for i, ax in enumerate(axarr):
    ax.grid(alpha=0.2)
    ax.set_xlabel(r'$\beta$', size=14)
    ax.set_title(r'$p=${:0.2f}'.format(ps[i]))

axarr[0].set_ylabel(r'linear rewards ($R_\ell)$', size=14)
f.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, -0.02), ncol=2)

# plt.savefig('out.png', dpi=150, bbox_inches='tight', facecolor='white')
plt.show()

# %%
def simAllRews(a, b, p, E, n):
    gamma = 0
    state = [0,0] # (attacker, honest)

    honestBlcs = 0
    attackBlcs = 0
    honestRews = 0
    attackRews = 0
    honestBern = 0
    attackBern = 0
    curTime    = 0
    lastState0 = 0
    lastAttBlc = 0
    prevBern   = 0
    for _ in range(n):
        attBlock = np.random.binomial(1, a)
        execRews = np.random.exponential()
        bernRews = np.random.binomial(1, p=p)
        curTime += execRews

        if state == [0,0]:
            if attBlock:
                if bernRews and execRews < (b-E):
                    state      = [1,0]
                    lastAttBlc = curTime
                    prevBern   = bernRews
                elif not bernRews and execRews < b:
                    state      = [1,0]
                    lastAttBlc = curTime
                    prevBern   = 0
                else:
                    attackBlcs += 1
                    attackRews += execRews
                    attackBern += bernRews
                    lastState0  = curTime
                    lastAttBlc  = curTime
            else:
                honestBlcs += 1
                honestRews += execRews
                honestBern += bernRews
                lastState0  = curTime
                lastAttBlc  = curTime
            continue

        if state == [1,0]:
            if attBlock:
                state = [2,0]
                lastAttBlc = curTime
                attackBern += bernRews + prevBern
                prevBern   = 0
            else:
                sample        = np.random.uniform()
                nextExecRews  = np.random.exponential()
                nextBern      = np.random.binomial(1, p=p)
                if sample < a:
                    attackBlcs += 2
                    attackRews += (curTime - lastState0) + nextExecRews
                    attackBern += (prevBern + nextBern)
                elif sample <= a + ((1-a)*gamma):
                    attackBlcs += 1
                    honestBlcs += 1
                    attackRews += (lastAttBlc - lastState0)
                    honestRews += (curTime - lastAttBlc) + nextExecRews
                    attackBern += prevBern
                    honestBern += nextBern
                else:
                    honestBlcs += 2
                    honestRews += (curTime - lastState0) + nextExecRews
                    # honest bern is a random trial
                    prevHonest  = np.random.binomial(1, p=p)
                    honestBern += (prevHonest + nextBern)
                curTime    += nextExecRews
                lastState0  = curTime
                lastAttBlc  = curTime
                prevBern    = 0
                state = [0,0]
            continue

        if attBlock:
            state[0] += 1
            lastAttBlc = curTime
        else:
            state[1] += 1

        diff = state[0] - state[1]
        if diff == 1:
            attackBlcs += state[0]
            if state[0] < 2:
                raise KeyError("here")
            attackBern += (state[0]-2) * p * E
            attackRews += (lastAttBlc - lastState0)

            # 0'' state
            remRews = (curTime - lastAttBlc)
            attBlock = np.random.binomial(1, a)
            execRews = np.random.exponential()
            bernRews = np.random.binomial(1, p=p)
            curTime += execRews
            if attBlock:
                attackBlcs += 1
                attackRews += (remRews + execRews)
                attackBern += bernRews
            else:
                honestBlcs += 1
                honestRews += (remRews + execRews)
                honestBern += bernRews

            lastState0  = curTime
            lastAttBlc  = curTime
            state = [0,0]
 
    return honestBlcs, attackBlcs, honestBern, attackBern, honestRews, attackRews

# %%
def simAllRewsRandomLinear(a, b, p, E, n):
    gamma = 0
    state = [0,0] # (attacker, honest)

    honestBlcs = 0
    attackBlcs = 0
    honestRews = 0
    attackRews = 0
    honestBern = 0
    attackBern = 0
    curTime    = 0
    lastState0 = 0
    lastAttBlc = 0
    prevBern   = 0
    for _ in range(n):
        attBlock = np.random.binomial(1, a)
        time     = np.random.exponential()
        execRews = np.random.normal(time, scale=1)
        bernRews = np.random.binomial(1, p=p)
        curTime += execRews

        if state == [0,0]:
            if attBlock:
                if bernRews and execRews < (b-E):
                    state      = [1,0]
                    lastAttBlc = curTime
                    prevBern   = bernRews
                elif not bernRews and execRews < b:
                    state      = [1,0]
                    lastAttBlc = curTime
                    prevBern   = 0
                else:
                    attackBlcs += 1
                    attackRews += execRews
                    attackBern += bernRews
                    lastState0  = curTime
                    lastAttBlc  = curTime
            else:
                honestBlcs += 1
                honestRews += execRews
                honestBern += bernRews
                lastState0  = curTime
                lastAttBlc  = curTime
            continue

        if state == [1,0]:
            if attBlock:
                state = [2,0]
                lastAttBlc = curTime
                attackBern += bernRews + prevBern
                prevBern   = 0
            else:
                sample        = np.random.uniform()
                nextExecRews  = np.random.exponential()
                nextBern      = np.random.binomial(1, p=p)
                if sample < a:
                    attackBlcs += 2
                    attackRews += (curTime - lastState0) + nextExecRews
                    attackBern += (prevBern + nextBern)
                elif sample <= a + ((1-a)*gamma):
                    attackBlcs += 1
                    honestBlcs += 1
                    attackRews += (lastAttBlc - lastState0)
                    honestRews += (curTime - lastAttBlc) + nextExecRews
                    attackBern += prevBern
                    honestBern += nextBern
                else:
                    honestBlcs += 2
                    honestRews += (curTime - lastState0) + nextExecRews
                    # honest bern is a random trial
                    prevHonest  = np.random.binomial(1, p=p)
                    honestBern += (prevHonest + nextBern)
                curTime    += nextExecRews
                lastState0  = curTime
                lastAttBlc  = curTime
                prevBern    = 0
                state = [0,0]
            continue

        if attBlock:
            state[0] += 1
            lastAttBlc = curTime
        else:
            state[1] += 1

        diff = state[0] - state[1]
        if diff == 1:
            attackBlcs += state[0]
            if state[0] < 2:
                raise KeyError("here")
            attackBern += (state[0]-2) * p * E
            attackRews += (lastAttBlc - lastState0)

            # 0'' state
            remRews = (curTime - lastAttBlc)
            attBlock = np.random.binomial(1, a)
            execRews = np.random.exponential()
            bernRews = np.random.binomial(1, p=p)
            curTime += execRews
            if attBlock:
                attackBlcs += 1
                attackRews += (remRews + execRews)
                attackBern += bernRews
            else:
                honestBlcs += 1
                honestRews += (remRews + execRews)
                honestBern += bernRews

            lastState0  = curTime
            lastAttBlc  = curTime
            state = [0,0]
 
    return honestBlcs, attackBlcs, honestBern, attackBern, honestRews, attackRews

# %%
simsRes = []
for a in alphas:
    temp1 = []
    for b in tqdm(simBetas):
        temp2 = []
        for p in ps:
            _, _, _, _, honestLin, attackLin = simAllRewsRandomLinear(a=a, b=b, p=p, E=1, n=int(1e5))
            temp2.append(attackLin/(attackLin+honestLin))
        temp1.append(temp2)
    simsRes.append(temp1)
simsRes = np.array(simsRes)
simsRes.shape
# Out:
# 100%|██████████| 17/17 [00:36<00:00,  2.13s/it]
# 100%|██████████| 17/17 [00:36<00:00,  2.17s/it]
# 100%|██████████| 17/17 [00:38<00:00,  2.28s/it]
# 100%|██████████| 17/17 [00:38<00:00,  2.29s/it]
# 100%|██████████| 17/17 [00:39<00:00,  2.30s/it]
# (5, 17, 3)

# %%
f, axarr = plt.subplots(ncols=3, figsize=(14,4))

colors = ['maroon', 'lightseagreen', 'darkmagenta', 'peru', 'dodgerblue'] 
handles, labels = [], []

for i in range(3):
    ax = axarr[i]
    for j, a in enumerate(alphas):
        line, = ax.plot(betas, theoRes[j,:,i], linewidth=0.8, color=colors[j], 
                        label=r'$\alpha$={:0.2f} theo'.format(a))
        if i == 0:
            handles.append(line)
            labels.append(r'$\alpha$={:0.2f} theo'.format(a))

for i in range(3):
    ax = axarr[i]
    for j, a in enumerate(alphas):
        marker, = ax.plot(simBetas, simsRes[j,:,i], marker='o', color=colors[j], linestyle='none', 
                          fillstyle='none', label=r'$\alpha$={:0.2f} sim'.format(a))
        if i == 0:
            handles.append(marker)
            labels.append(r'$\alpha$={:0.2f} sim'.format(a))


for i, ax in enumerate(axarr):
    ax.grid(alpha=0.2)
    ax.set_xlabel(r'$\beta$', size=14)
    ax.set_title(r'$p=${:0.2f}'.format(ps[i]))

axarr[0].set_ylabel(r'linear rewards ($R_\ell)$', size=14)
f.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, -0.02), ncol=2)

# plt.savefig('out.png', dpi=150, bbox_inches='tight', facecolor='white')
plt.show()

# %% [markdown]
# # sympy integration

# %%
x = sps.Normal('X', 0 , 1)
sps.P(x > 1).evalf()
# Out:
# 0.158655253931457

# %%
p, beta, C, t, sigma = sp.symbols('p beta C t sigma')
F_t = sp.simplify((1-p) * sps.P(sps.Normal('X', t, sigma) < beta))
F_t.evalf(subs={p:0.5, t:1, sigma:1, C:1, beta:5})
# Out:
# 0.499984164379083

# %%
sp.integrate(F_t, t)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     210
# --> 211                         monom[indices[base]] = exp
#     212                     except KeyError:
#
# KeyError: Abs(arg(beta) - 2*arg(sigma) + arg(1 - t/beta) + pi)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     808     try:
# --> 809         p = Poly(expr, s)
#     810         if p.degree() == 0:
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polytools.py in __new__(cls, rep, *gens, **args)
#     181             else:
# --> 182                 return cls._from_expr(rep, opt)
#     183
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polytools.py in _from_expr(cls, rep, opt)
#     310         """Construct a polynomial from an expression. """
# --> 311         rep, opt = _dict_from_expr(rep, opt)
#     312         return cls._from_dict(rep, opt)
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _dict_from_expr(expr, opt)
#     367     if opt.gens:
# --> 368         rep, gens = _dict_from_expr_if_gens(expr, opt)
#     369     else:
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _dict_from_expr_if_gens(expr, opt)
#     306     """Transform an expression into a multinomial form given generators. """
# --> 307     (poly,), gens = _parallel_dict_from_expr_if_gens((expr,), opt)
#     308     return poly, gens
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215                         else:
# --> 216                             raise PolynomialError("%s contains an element of "
#     217                                                   "the set of generators." % factor)
#
# PolynomialError: Abs(arg(beta) - 2*arg(sigma) + arg(1 - t/beta) + pi) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     210
# --> 211                         monom[indices[base]] = exp
#     212                     except KeyError:
#
# KeyError: Abs(arg(beta) - 2*arg(sigma) + arg(1 - t/beta) + pi)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in reduce_rational_inequalities(exprs, gen, relational)
#     246             try:
# --> 247                 (numer, denom), opt = parallel_poly_from_expr(
#     248                     (numer, denom), gen)
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4503     opt = options.build_options(gens, args)
# -> 4504     return _parallel_poly_from_expr(exprs, opt)
#    4505
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4554
# -> 4555     reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4556     if not opt.gens:
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr(exprs, opt)
#     331     if opt.gens:
# --> 332         reps, gens = _parallel_dict_from_expr_if_gens(exprs, opt)
#     333     else:
#
# /usr/local/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215                         else:
# --> 216                             raise PolynomialError("%s contains an element of "
#     217                                                   "the set of generators." % factor)
#
# PolynomialError: Abs(arg(beta) - 2*arg(sigma) + arg(1 - t/beta) + pi) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     817             try:
# --> 818                 rv = reduce_rational_inequalities([[ie]], s)
#     819             except PolynomialError:
#
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in reduce_rational_inequalities(exprs, gen, relational)
#     249             except PolynomialError:
# --> 250                 raise PolynomialError(filldedent('''
#     251                     only polynomials and rational functions are
#
# PolynomialError:
# only polynomials and rational functions are supported in this context.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-c054d44f291a> in <module>
# ----> 1 sp.integrate(F_t, t)
#
# /usr/local/lib/python3.8/site-packages/sympy/integrals/integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1565
#    1566     if isinstance(integral, Integral):
# -> 1567         return integral.doit(**doit_flags)
#    1568     else:
#    1569         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /usr/local/lib/python3.8/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     545             if isinstance(function, Piecewise):
#     546                 if len(xab) == 1:
# --> 547                     antideriv = function._eval_integral(xab[0],
#     548                         **eval_kwargs)
#     549                 else:
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in _eval_integral(self, x, _first, **kwargs)
#     393                 else:
#     394                     return ipw.integrate(x, **kwargs)
# --> 395             irv = self._handle_irel(x, handler)
#     396             if irv is not None:
#     397                 return irv
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in _handle_irel(self, x, handler)
#     339                         continue  # an impossible combination
#     340                     cond = t
# --> 341                 expr = handler(self.xreplace(reps))
#     342                 if isinstance(expr, self.func) and len(expr.args) == 1:
#     343                     expr, econd = expr.args[0]
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in handler(ipw)
#     390             def handler(ipw):
#     391                 if isinstance(ipw, self.func):
# --> 392                     return ipw._eval_integral(x, _first=False, **kwargs)
#     393                 else:
#     394                     return ipw.integrate(x, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in _eval_integral(self, x, _first, **kwargs)
#     399         # handle a Piecewise from -oo to oo with and no x-independent relationals
#     400         # -----------------------------------------------------------------------
# --> 401         ok, abei = self._intervals(x)
#     402         if not ok:
#     403             from sympy.integrals.integrals import Integral
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in _intervals(self, sym, err_on_Eq)
#     641         reps = {}
#     642         for r in keys:
# --> 643             ok, s = _solve_relational(r)
#     644             if ok != True:
#     645                 return False, ok
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/piecewise.py in _solve_relational(r)
#     612                 return nonsymfail(r)
#     613             try:
# --> 614                 rv = _solve_inequality(r, sym)
#     615             except NotImplementedError:
#     616                 return False, 'Unable to solve relational %s for %s.' % (r, sym)
#
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     818                 rv = reduce_rational_inequalities([[ie]], s)
#     819             except PolynomialError:
# --> 820                 rv = solve_univariate_inequality(ie, s)
#     821             # remove restrictions wrt +/-oo that may have been
#     822             # applied when using sets to simplify the relationship
#
# /usr/local/lib/python3.8/site-packages/sympy/solvers/inequalities.py in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     480     else:
#     481         e = expr.lhs - expr.rhs
# --> 482         period = periodicity(e, gen)
#     483         if period == S.Zero:
#     484             e = expand_mul(e)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
# ...
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     518                 g = compogen(g_s[start_index:], symbol)
#     519                 if g not in (orig_f, f): # Fix for issue 12620
# --> 520                     period = periodicity(g, symbol)
#     521                     if period is not None:
#     522                         break
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     483         coeff, g = f.as_independent(symbol, as_Add=False)
#     484         if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485             period = periodicity(g, symbol)
#     486         else:
#     487             period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     490         k, g = f.as_independent(symbol)
#     491         if k is not S.Zero:
# --> 492             return periodicity(g, symbol)
#     493
#     494         period = _periodicity(g.args, symbol)
#
# /usr/local/lib/python3.8/site-packages/sympy/calculus/util.py in periodicity(f, symbol, check)
#     400         raise NotImplementedError("Cannot use symbol of kind %s" % symbol.kind)
#     401     temp = Dummy('x', real=True)
# --> 402     f = f.subs(symbol, temp)
#     403     symbol = temp
#     404
#
# /usr/local/lib/python3.8/site-packages/sympy/core/basic.py in subs(self, *args, **kwargs)
#    1038             rv = self
#    1039             for old, new in sequence:
# -> 1040                 rv = rv._subs(old, new, **kwargs)
#    1041                 if not isinstance(rv, Basic):
#    1042                     break
#
# /usr/local/lib/python3.8/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.8/site-packages/sympy/core/basic.py in _subs(self, old, new, **hints)
#    1152         rv = self._eval_subs(old, new)
#    1153         if rv is None:
# -> 1154             rv = fallback(self, old, new)
#    1155         return rv
#    1156
#
# /usr/local/lib/python3.8/site-packages/sympy/core/basic.py in fallback(self, old, new)
#    1124                 if not hasattr(arg, '_eval_subs'):
#    1125                     continue
# -> 1126                 arg = arg._subs(old, new, **hints)
#    1127                 if not _aresame(arg, args[i]):
#    1128                     hit = True
#
# /usr/local/lib/python3.8/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.8/site-packages/sympy/core/basic.py in _subs(self, old, new, **hints)
#    1152         rv = self._eval_subs(old, new)
#    1153         if rv is None:
# -> 1154             rv = fallback(self, old, new)
#    1155         return rv
#    1156
#
# /usr/local/lib/python3.8/site-packages/sympy/core/basic.py in fallback(self, old, new)
#    1129                     args[i] = arg
#    1130             if hit:
# -> 1131                 rv = self.func(*args)
#    1132                 hack2 = hints.get('hack2', False)
#    1133                 if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# /usr/local/lib/python3.8/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, *args, **options)
#     464
#     465         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466         result = super().__new__(cls, *args, **options)
#     467         if evaluate and isinstance(result, cls) and result.args:
#     468             _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# /usr/local/lib/python3.8/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, *args, **options)
#     305
#     306         if evaluate:
# --> 307             evaluated = cls.eval(*args)
#     308             if evaluated is not None:
#     309                 return evaluated
#
# /usr/local/lib/python3.8/site-packages/sympy/functions/elementary/complexes.py in eval(cls, arg)
#     763             return periodic_argument(arg, oo)
#     764         if not arg.is_Atom:
# --> 765             c, arg_ = factor_terms(arg).as_coeff_Mul()
#     766             if arg_.is_Mul:
#     767                 arg_ = Mul(*[a if (sign(a) not in (-1, 1)) else
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1265         return rv
#    1266     expr = sympify(expr)
# -> 1267     return do(expr)
#    1268
#    1269
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1240         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1241         if p.is_Add:
# -> 1242             list_args = [do(a) for a in Add.make_args(p)]
#    1243             # get a common negative (if there) which gcd_terms does not remove
#    1244             if not any(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is None
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1240         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1241         if p.is_Add:
# -> 1242             list_args = [do(a) for a in Add.make_args(p)]
#    1243             # get a common negative (if there) which gcd_terms does not remove
#    1244             if not any(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is None
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1228                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1229             args = expr.args
# -> 1230             newargs = tuple([do(i) for i in args])
#    1231             if newargs == args:
#    1232                 return expr
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1228                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1229             args = expr.args
# -> 1230             newargs = tuple([do(i) for i in args])
#    1231             if newargs == args:
#    1232                 return expr
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1261         elif p.args:
#    1262             p = p.func(
# -> 1263                 *[do(a) for a in p.args])
#    1264         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265         return rv
#
# /usr/local/lib/python3.8/site-packages/sympy/core/exprtools.py in do(expr)
#    1249             special = {}
#    1250             for i, a in enumerate(list_args):
# -> 1251                 b, e = a.as_base_exp()
#    1252                 if e.is_Mul and e != Mul(*e.args):
#    1253                     list_args[i] = Dummy()
#
# /usr/local/lib/python3.8/site-packages/sympy/core/mul.py in as_base_exp(self)
#    1245             if e1 is None:
#    1246                 e1 = e
# -> 1247             elif e != e1 or nc > 1:
#    1248                 return self, S.One
#    1249             bases.append(b)
#
# /usr/local/lib/python3.8/site-packages/sympy/core/numbers.py in __ne__(self, other)
#    2255
#    2256     def __ne__(self, other):
# -> 2257         return not self == other
#    2258
#    2259     def __gt__(self, other):
#
# /usr/local/lib/python3.8/site-packages/sympy/core/numbers.py in __eq__(self, other)
#    2251             return (self.p == other)
#    2252         elif isinstance(other, Integer):
# -> 2253             return (self.p == other.p)
#    2254         return Rational.__eq__(self, other)
#    2255
#
# KeyboardInterrupt:
